# %% [markdown]
# # WEIT x DataStation Team Mission 1.
#
# - 아래의 15개의 미션을 제출 기간 내 수행하시면 됩니다. / ** "개별 제출" **
# - 첫 5개 미션은 개인 스스로 풀어보고, 나머지 미션은 팀원들과 같이 풀어보세요.
# - Chat GPT + 교재 + 팀스터디 모두 활용하여 풀어보시길 바랍니다.
# - 미션 미제출시, 수료증 발급에 제한이 될 수 있습니다.
#
#
# - **기한 : 24년 4월 3일 23시 59분까지 / 이후 제출 인정 불가**
# - **양식 :**
#     - 제목 : "위아이티5기_팀명_이름_Mission1"
#     - 첨부파일 : 해당 Mission 파일
#     - 개별 제출
# - **제출처 : woghkszhf@naver.com**

# %% [markdown]
# **1. 자료구조 Dictionary를 이용하여, if 문 없이 연도를 입력했을 때 윤년/평년을 판별하여 출력하는 프로그램을 생성하시오.**

# %%
def is_leap_year(year) :
    # 윤년 : 4로 나눈 나머지가 0이고 100으로 나눈 나머지가 0이 아니거나 400으로 나눈 나머지가 0인 경우
    return (year % 4 == 0) and (year % 100 != 0 or year % 400 == 0)

year = int(input("연도를 입력하세요: "))
leap_year = is_leap_year(year)                          # 입력된 연도를 is_leap_year() 함수에 전달하여 윤년인지 아닌지 판별

result = {True: "윤년", False: "평년"}[leap_year]        # leap_year를 키로 사용하여 해당하는 값을 가져옴

print("{0}년은 {1}입니다.".format(year,result))
# Out:
# 2024년은 윤년입니다.

# %% [markdown]
# **2. 키와 몸무게를 입력받아 BMI 수치를 계산하는 프로그램을 제작하고, 새로운 값을 입력할 때마다, result_list에 결과를 추가하시오.**
#
# * 조건 : 새로운 값을 입력 할 때 마다 기존의 데이터가 삭제되지 않고 추가되어야 합니다.
#
# ![image.png](attachment:image.png)

# %%
result_list = [ ]

def calculate_bmi(height, weight) :
    return weight / (height /100) ** 2                         # cm로 받은 키를 m 단위로 변환한 후 제곱하여 m2로 만들어줌

while True:
    height = float(input("키를 입력하세요(cm): "))
    weight = float(input("몸무게를 입력하세요(kg): "))

    bmi = calculate_bmi(height, weight)
    result_list.append(bmi)

    print("BMI 수치는 {:.2f}입니다.".format(bmi))                # 소수점 둘째자리까지 출력

    continue_input = input("더 입력하시겠습니까? (yes/no): ")
    if continue_input.lower() != 'yes':                         # continue_input 변수에 저장된 문자열을 소문자로 변환 후 비교
        break

print("입력된 BMI 수치: ", result_list)
# Out:
# BMI 수치는 19.05입니다.
# BMI 수치는 17.30입니다.
# 입력된 BMI 수치:  [19.05197378448407, 17.301038062283737]

# %% [markdown]
# **3. A 학생의 과목별 점수가 아래와 같을 때, 이 점수를 딕셔너리 형태로 선언하고, 평균을 계산하오**
#
# * A : 국어 75, 영어 53, 수학 90, 사회 46, 한국사 60, 세계사 70, 과학, 34
# * 과목명은 Key값, 점수는 Value 값

# %%
# A 학생의 과목별 점수 딕셔너리 선언
scores = {
    '국어'   : 75,
    '영어'   : 53,
    '수학'   : 90,
    '사회'   : 46,
    '한국사' : 60,
    '세계사' : 70,
    '과학'   : 34
}

# 과목별 점수 합산
total_score = sum(scores.values())

# 평균 계산
average_score = total_score / len(scores)

print("과목별 점수:", scores)
print("평균 점수:", average_score)
# Out:
# 과목별 점수: {'국어': 75, '영어': 53, '수학': 90, '사회': 46, '한국사': 60, '세계사': 70, '과학': 34}
# 평균 점수: 61.142857142857146

# %% [markdown]
# **4. 어떤 수를 입력했을 때, 입력한 수가 홀수이면 True, 짝수이면 False를 출력하는 프로그램을 제작하시오**
#
# * if문을 사용 하지 않고 제작

# %%
def is_odd(number):
    return number % 2 == 1

number= int(input("정수를 입력하세요: "))
print(is_odd(number))
# Out:
# True

# %% [markdown]
# **5. For 반복문을 이용하여, 1부터 입력받은 수 까지 제곱 합을 구하는 프로그램을 만드시오.**
#
# Ex ) 1² + 2² + 3² + 4² + ...  + n²

# %%
def sum_of_squares(n) :
    total = 0                       # 초기값 설정
    for i in range(1, n+1):         # range() 함수는 n+1로 코드를 작성해야 n까지의 숫자를 생성함
        total += i**2
    return total

n = int(input("정수를 입력하세요: "))
result = sum_of_squares(n)
print("1부터", n, "까지의 제곱의 합은", result, "입니다.")
# Out:
# 1부터 5 까지의 제곱의 합은 55 입니다.

# %% [markdown]
# ## Team Mission
#
# - 사무용품을 렌탈해주는 회사에서 발생한 데이터(01_Data.csv)파일을 분석하고자 합니다.
# - Excel, R, SPSS등 다른 프로그램은 사용 하지 않고, 오르지 Python으로 아래의 문제를 해결해 보세요.

# %% [markdown]
# **6. 데이터 파일을 df1 변수로 선언하고, 데이터의 열개수와 행개수를 계산하시오.**

# %%
import pandas as pd   # pandas 패키지 로드

df1 = pd.read_csv("01_Data.csv")   # 데이터 파일을 df1 변수로 선언
num_columns = len(df1.columns)                      # 열 개수
num_rows = len(df1)                                 # 행 개수

print("열 개수:",num_columns)
print("행 개수:",num_rows)
# Out:
# 열 개수: 20
# 행 개수: 51301

# %% [markdown]
# **7. 데이터에서 고객들의 유입경로(Channel)을 분석하고자 한다. 유입경로(Channel)중 가장 많은 고객이 유입된 경로를 확인하시오.**

# %%
 # 유입 경로(channel)별 고객 수를 계산 후 위의 1개 항목만 출력
channel_counts = df1['Channel'].value_counts().head(1)
channel_counts
# Out:
# Channel
# 영업방판    23767
# Name: count, dtype: int64

# %% [markdown]
# **8. 데이터에서 고객들이 가장 많이 계약한 제품군(Product_Type)을 분석하고자 한다. 제품군(Product_Type)에는 어떤 데이터가 있는지 확인하시오.**

# %%
# 제품군(Product_Type)을 내림차순으로 정렬하여 데이터를 확인
product_types = df1['Product_Type'].value_counts()
product_types
# Out:
# Product_Type
# DES-1     39133
# DES-2      8996
# DES-3A     2081
# ERA         644
# DES-R4      327
# MMC         120
# Name: count, dtype: int64

# %% [markdown]
# **9. 데이터에서 고객들이 결제하는 은행(Bank)를 확인하고자 한다. 결제은행(Bank)항목에서 '신한카드'로 결제하는 고객들의 수를 확인하시오.**

# %%
# 신한카드로 결제하는 고객의 데이터만 추출한 후 행의 개수로 고객들의 수를 확인
shinhan_customers = df1.query("Bank == '신한카드'").shape[0]
shinhan_customers
# Out:
# 1532

# %% [markdown]
# **10. 데이터에서 고객들이 월별로 지출하는, 월랜탈비용(Amount_Month)를 분석하고자 한다. 월랜탈비용(Amount_Month)과 계약기간(Term)을 곱하여, 한명의 고객이 지불하는 총 계약금액을 계산하고, 새로운 파생변수로 (Total_Amount)로 선언 하시오.**

# %%
df1['Total_Amount'] = df1['Amount_Month'] * df1['Term']   # 새로운 파생변수 Total_Amount 선언
df1                                                       # Total_Amount 변수가 만들어진 것을 확인
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 0          1   66758234         렌탈          일반계약    영업방판  2019-05-06    60
# 1          2   66755948         렌탈          교체계약    영업방판  2020-02-20    60
# 2          3   66756657         렌탈          일반계약  홈쇼핑/방송  2019-02-28    60
# 3          4   66423450        멤버십        멤버십3유형     재계약  2019-05-13    12
# 4          5   66423204        멤버십        멤버십3유형     재계약  2019-05-10    12
# ...      ...        ...        ...           ...     ...         ...   ...
# 51296  51298   66579515         렌탈        프로모션계약   대형마트A  2019-03-01    60
# 51297  51299   66799558         렌탈          일반계약   대형마트A  2019-04-01    60
# 51298  51300   66799197         렌탈        프로모션계약    영업방판  2019-04-01    39
# 51299  51301   66792778         렌탈          일반계약  홈쇼핑/방송  2020-02-06    60
# 51300  51302   66799607         렌탈          일반계약  홈쇼핑/방송  2019-04-24    60
#
# ...

# %% [markdown]
# **11. 유입경로(Channel)에서 '영업방판'으로 유입된 고객들을 분석하고자 한다.'영업방판'으로 유입된 고객들의 월랜탈비용(Amount_Month)의 평균(mean)과 중앙값(median)의 차이를 계산 하시오.**

# %%
amount_sales = df1.loc[df1['Channel'] == '영업방판', 'Amount_Month']

difference = amount_sales.mean() - amount_sales.median()

print("평균과 중앙값의 차이:", difference)
# Out:
# 평균과 중앙값의 차이: 3422.794631211349

# %% [markdown]
# **12. 유입경로(Channel)에서 '영업방판'으로 유입된 고객들 중, 제품군(Product_Type) 별 월랜탈비용(Amount_Month)의 합(sum)을 계산하여 result3.xlsx 파일로 저장하시오.**

# %%
# 영업방판으로 유입된 고객 중, 제품군(Product_Type)별 월랜탈비용(Amount_Month)의 합 계산
result3 = df1.query("Channel == '영업방판'").groupby('Product_Type')[['Amount_Month']].sum()

# 결과를 Excel 파일로 저장하기
result3.to_excel('result3.xlsx')

# %% [markdown]
# **13. 유입경로(Channel)에서 '대형마트A'로 유입된 고객들 중, 연체건수(Overdue_count)가 높은 상위 30명의 계약 명단을 추출하여 result4.xlsx 저장하시오.**

# %%
# 대형마트A로 유입된 고객 중, 연체건수(Overdue_count)가 높은 상위 30명 추출
result4 = df1.query("Channel == '대형마트A'").sort_values('Overdue_count', ascending = False).head(30)

# 결과를 Excel 파일로 저장하기
result4.to_excel('result4.xlsx')

# %% [markdown]
# **14. 월랜탈비용(Amount_Month)이 15만원 이상인 고객들 중 판매유형(Sales_Type)이 '렌탈'에 해당하는 고객만 추출하여, 해당 데이터의 행(index) 개수를 확인하시오.**

# %%
# 월랜탈비용(Amount_month)이 15만원 이상이고, 판매유형(Sales_Type)이 렌탈에 해당하는 고객 추출 후 행 개수 확인
rental_customers = df1.query("Amount_Month >= 150000 and Sales_Type == '렌탈'").shape[0]
rental_customers
# Out:
# 141

# %% [markdown]
# **15. 제품군(Product_Type)중 빈도수가 가장 높은 상위 3개의 항목을 추출하여, df2로 선언한 뒤, 계약일자(Datetime)에 따른 월렌탈비용(Amount_Month)의 합을 계산해 result5.xlsx파일로 저장하시오.**

# %%
# 제품군(Product_Type)중 빈도수가 가장 높은 상위 3개의 항목을 추출한 후 df2로 선언
top_product_type = df1['Product_Type'].value_counts().head(3).index      # .index를 이용해 빈도수를 제외한 항목만 저장
df2 = df1[df1['Product_Type'].isin(top_product_type)]                    # isin()을 사용하여 각 요소가 top_product_type에 포함되는지 확인한 후 해당 행만 df2에 저장

# 계약일자(Datetime)에 따른 월렌탈비용(Amount_Month)의 합 계산
result5 = df2.groupby('Datetime')[['Amount_Month']].sum()

# 결과를 Excel 파일로 저장하기
result5.to_excel('result5.xlsx')
