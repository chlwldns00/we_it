# %% [markdown]
# ### 인터랙티브 그래프

# %% [markdown]
# - 마우스 움직임에 반응하여 실시간으로 모양이 변하는 그래프
#     - 자유롭게 조작하면서 여러가지 부분을 살펴볼수있다
#     - HTML 포맷으로 저장해도 조작가능

# %%
# !pip install plotly
# !pip install jupyter-dash
# Out:
# Requirement already satisfied: plotly in c:\users\home\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\home\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: ipykernel in c:\users\home\anaconda3\lib\site-packages (from jupyter-dash) (6.15.2)
# Requirement already satisfied: ipython in c:\users\home\anaconda3\lib\site-packages (from jupyter-dash) (7.31.1)
# Requirement already satisfied: flask in c:\users\home\anaconda3\lib\site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: retrying in c:\users\home\anaconda3\lib\site-packages (from jupyter-dash) (1.3.4)
# Collecting dash
#   Downloading dash-2.16.1-py3-none-any.whl (10.2 MB)
#      --------------------------------------- 10.2/10.2 MB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\home\anaconda3\lib\site-packages (from jupyter-dash) (2.28.1)
# Requirement already satisfied: nest-asyncio in c:\users\home\anaconda3\lib\site-packages (from jupyter-dash) (1.5.5)
# Collecting ansi2html
#   Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\home\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\home\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.9.0)
# Requirement already satisfied: importlib-metadata in c:\users\home\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.11.3)
# Requirement already satisfied: setuptools in c:\users\home\anaconda3\lib\site-packages (from dash->jupyter-dash) (63.4.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\home\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.9.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\home\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\home\anaconda3\lib\site-packages (from flask->jupyter-dash) (3.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\home\anaconda3\lib\site-packages (from flask->jupyter-dash) (8.0.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (7.3.4)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.1.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (23.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: packaging in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (21.3)
# Requirement already satisfied: debugpy>=1.0 in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: psutil in c:\users\home\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: colorama in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: pygments in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.15.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.20)
# Requirement already satisfied: decorator in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: backcall in c:\users\home\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\home\anaconda3\lib\site-packages (from requests->jupyter-dash) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\home\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\home\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\home\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.26.11)
# Requirement already satisfied: six>=1.7.0 in c:\users\home\anaconda3\lib\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\home\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\home\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\home\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (4.11.1)
# Requirement already satisfied: entrypoints in c:\users\home\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\home\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\home\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\home\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\home\anaconda3\lib\site-packages (from importlib-metadata->dash->jupyter-dash) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\home\anaconda3\lib\site-packages (from packaging->ipykernel->jupyter-dash) (3.0.9)
# Requirement already satisfied: pywin32>=1.0 in c:\users\home\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash) (302)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, ansi2html, dash, jupyter-dash
# Successfully installed ansi2html-1.9.1 dash-2.16.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 jupyter-dash-0.4.2

# %%
import pandas as pd
mpg = pd.read_csv('../Data/mpg.csv')

# %% [markdown]
# - 산점도

# %%
import plotly.express as px
px.scatter(data_frame = mpg, x = 'cty', y = 'hwy', color = 'drv')

# %% [markdown]
# - 막대그래프

# %%
# 자동차 종류별 빈도 구하기
df = mpg.groupby('category', as_index = False) \
        .agg(n = ('category', 'count'))
df
# Out:
#      category   n
# 0     2seater   5
# 1     compact  47
# 2     midsize  41
# 3     minivan  11
# 4      pickup  33
# 5  subcompact  35
# 6         suv  62

# %%
px.bar(data_frame = df, x = 'category', y = 'n', color = 'category')

# %% [markdown]
# - 선그래프

# %%
# economics 불러오기
economics = pd.read_csv('../Data/economics.csv')                  

# 선 그래프 만들기
px.line(data_frame = economics, x = 'date', y = 'psavert')

# %% [markdown]
# - 상자그림

# %%
# 상자 그림 만들기
px.box(data_frame = mpg, x = 'drv', y = 'hwy', color = 'drv')
